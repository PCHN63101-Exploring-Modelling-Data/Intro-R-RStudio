# %% [markdown]
# # Summary
#
# To recap: We've covered the RStudio environment inlcuding the Source, Console, Environment and Output panes as well as the purpose of a script and how to run one. We then looked at the R language in more detail. We covered assigning values to objects and the different types of objects that exist. We then looked at vectors before finishing with functions.
#
# Make a note of anything you are confused or unsure about and we can address it during the in-person session, when you will also have the chance to put this learning into practice.
